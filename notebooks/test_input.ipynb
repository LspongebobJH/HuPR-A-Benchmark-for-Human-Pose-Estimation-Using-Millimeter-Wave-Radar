# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_869385/2658766297.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import pickle
import numpy as np

from PIL import Image
import cv2

# %% [markdown]
# # raw data

# %%
path = "/home/ubuntu/hupr/raw_data/iwr1843/HuPR/{which}/{direc}/adc_data.bin"

# %%
s1h = np.fromfile(path.format(which='single_1', direc='hori'))

# %%
s1h.shape
# Out:
# (58982400,)

# %% [markdown]
# # video

# %%
img_path = "/home/ubuntu/hupr/visualization/single_{idx}/"

# %%
import cv2
import os

for idx in [16, 38, 40, 41, 42,
               17, 39,  244, 245, 246, 249, 250, 251, 252, 253, 254,
               247, 248, 255, 256]:
image_folder = img_path.format(idx='15')
video_name = os.path.join(image_folder, 'video.avi')

images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
images.sort()
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 1, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()
# Out:
#   Cell In[14], line 6
#     247, 248, 255, 256]
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # model output

# %%
vis_path = "/home/ubuntu/hupr/visualization/single_{which}/{frame:09d}.png"

# %%
Image.open(vis_path.format(which='15', frame=0)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=1)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=2)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=17)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=18)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=19)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=20)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=21)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=22)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=23)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=100)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=110)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=113)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=114)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=115)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=116)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=120)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=130)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=150)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=160)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=170)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=180)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=190)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
Image.open(vis_path.format(which='15', frame=200)).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# # preprocessing visualization

# %%
pre_vis_path = "/home/ubuntu/hupr/data/HuPR/single_{which}/visualization/{frame:09d}.png"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np

# %%
img = mpimg.imread(pre_vis_path.format(which=15, frame=0))

# %%
img.shape
# Out:
# (700, 1000, 4)

# %%
plt.imshow(img)
